# %%
import pandas as pd
import time

# %% [markdown]
# # customers table

# %%
customers_df=pd.read_csv("H:\IIT-M GUVI\Projects capstone\Project2\Customers.csv",encoding='latin1')
customers_df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customers_df.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
total_rows=customers_df.shape[0]
total_rows
# Out:
# 15266

# %%
print(customers_df.isnull().sum())
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
((customers_df.isnull().sum().sum())/total_rows)*100
# Out:
# 0.0655050438883794

# %%
customers_df['State Code']=customers_df['State Code'].fillna('NPO')

# %%
customers_df['Birthday'] = pd.to_datetime(customers_df['Birthday'])
customers_df['Birthday'] = customers_df['Birthday'].dt.strftime('%m-%d-%Y')# converting to required format

# %%
customers_df['Birthday'] = pd.to_datetime(customers_df['Birthday'])

# %%
customers_df.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\customers_df_new.csv",index=False)

# %%
print(customers_df.isnull().sum())
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
customers_df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customers_df.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %% [markdown]
# # Exchange rates table

# %%
exchange_rates_df=pd.read_csv("H:\IIT-M GUVI\Projects capstone\Project2\Exchange_Rates.csv")
exchange_rates_df
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
print(exchange_rates_df.isnull().sum())
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exchange_rates_df.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
exchange_rates_df['Date'] = pd.to_datetime(exchange_rates_df['Date'])

# %%
exchange_rates_df['Date'] = exchange_rates_df['Date'].dt.strftime('%m-%d-%Y')# converting to required format

# %%
exchange_rates_df['Date'] = pd.to_datetime(exchange_rates_df['Date'])

# %%
exchange_rates_df
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates_df = exchange_rates_df.rename(columns={'Currency': 'Currency Code'})
exchange_rates_df
# Out:
#             Date Currency Code  Exchange
# 0     2015-01-01           USD    1.0000
# 1     2015-01-01           CAD    1.1583
# 2     2015-01-01           AUD    1.2214
# 3     2015-01-01           EUR    0.8237
# 4     2015-01-01           GBP    0.6415
# ...          ...           ...       ...
# 11210 2021-02-20           USD    1.0000
# 11211 2021-02-20           CAD    1.2610
# 11212 2021-02-20           AUD    1.2723
# 11213 2021-02-20           EUR    0.8238
# 11214 2021-02-20           GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates_df.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object

# %%
exchange_rates_df.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\exchange_rates_df_new.csv",index=False)

# %% [markdown]
# # Products table

# %%
products_df=pd.read_csv("H:\IIT-M GUVI\Projects capstone\Project2\Products.csv")
products_df
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
print(products_df.isnull().sum())
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products_df.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
products_df['Unit Cost USD'] = products_df['Unit Cost USD'].replace({'\$': '', ',': ''}, regex=True).astype(float)
products_df['Unit Price USD'] = products_df['Unit Price USD'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
products_df
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
products_df.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
products_df.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\products_df_new.csv",index=False)

# %% [markdown]
# # Sales table

# %%
sales_df=pd.read_csv("H:\IIT-M GUVI\Projects capstone\Project2\Sales.csv")
sales_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
sales_df['Order Date'] = pd.to_datetime(sales_df['Order Date'])#converting to datetime datatypes

# %%
sales_df['Order Date'] = sales_df['Order Date'].dt.strftime('%m-%d-%Y')# converting to required format

# %%
sales_df['Order Date'] = pd.to_datetime(sales_df['Order Date'])#converting to datetime datatypes

# %%
print(sales_df.isnull().sum())
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
total_rows=sales_df.shape[0] # number of rows

# %%
((sales_df.isnull().sum().sum())/total_rows)*100 #percentage of null values
# Out:
# 79.064626932129

# %%
sales_df.drop('Delivery Date',axis=1,inplace=True) # dropped the column which had null values more than 50%
sales_df
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
sales_df.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
sales_df.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\sales_df_new.csv",index=False)

# %% [markdown]
# # Stores table

# %%
stores_df=pd.read_csv("H:\IIT-M GUVI\Projects capstone\Project2\Stores.csv")
stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
stores_df['Open Date'] = pd.to_datetime(stores_df['Open Date'])#converting to datetime datatypes
stores_df['Open Date'] = stores_df['Open Date'].dt.strftime('%m-%d-%Y')# converting to required format

# %%
stores_df['Open Date'] = pd.to_datetime(stores_df['Open Date'])#converting to datetime datatypes

# %%
print(stores_df.isnull().sum())
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
stores_df=stores_df.dropna()

# %%
stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 61        62  United States                  South Dakota         1120.0
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
stores_df.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object

# %%
stores_df.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\stores_df_new.csv",index=False)

# %% [markdown]
# # Merging of dataframes

# %%
customers_sales_merged=pd.merge(customers_df,sales_df,on='CustomerKey')
customers_sales_merged
# Out:
#        CustomerKey  Gender              Name                 City State Code  \
# 0              301  Female     Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female      Madison Hull           MOUNT BUDD         WA
# 2              325  Female      Madison Hull           MOUNT BUDD         WA
# 3              325  Female      Madison Hull           MOUNT BUDD         WA
# 4              325  Female      Madison Hull           MOUNT BUDD         WA
# ...            ...     ...               ...                  ...        ...
# 62879      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62880      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62881      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62882      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 62883      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customers_sales_merged.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\customers_sales_merged.csv",index=False)

# %%
products_sales_merged=pd.merge(products_df,sales_df,on='ProductKey')
products_sales_merged.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 2           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 3           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 4           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           6.62           12.99             101     MP4&MP3            1
# 3           6.62           12.99             101     MP4&MP3            1
# 4           6.62           12.99             101     MP4&MP3            1
#
#   Category  Order Number  Line Item Order Date  CustomerKey  StoreKey  \
# ...

# %%
products_sales_merged.to_csv("H:\IIT-M GUVI\Projects capstone\Project2\products_sales_merged.csv",index=False)

# %%
exchange_sales_merged=pd.merge(exchange_rates_df,sales_df,on='Currency Code')
exchange_sales_merged
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 exchange_sales_merged=pd.merge(exchange_rates_df,sales_df,on='Currency Code')
#       2 exchange_sales_merged
#
# File ~\anaconda3\envs\Manishma\Lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File ~\anaconda3\envs\Manishma\Lib\site-packages\pandas\core\reshape\merge.py:885, in _MergeOperation.get_result(self, copy)
#     881     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# ...

# %% [markdown]
# # connecting to mysql

# %%
import mysql.connector
con=mysql.connector.connect(
    host='localhost',
    user='root',
    password='Omsairam_10'
)
cursor=con.cursor()
cursor

# %%
query='create database DataSpark'
cursor.execute(query)

# %%
con=mysql.connector.connect(
    host='localhost',
    user='root',
    password='Omsairam_10',
    database='DataSpark'
)
cursor=con.cursor()
cursor

# %%
#create table customer details
create_table_query="""create table customers_details(CustomerKey int,
                                        Gender varchar(200),
                                        Name varchar(200),
                                        City varchar(200),
                                        StateCode varchar(100),
                                        State varchar(200),
                                        ZipCode varchar(100),
                                        Country varchar(200),
                                        Continent varchar(200),
                                        Birthday date
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO customers_details(CustomerKey, Gender, Name, City, StateCode, State, ZipCode, Country, Continent, Birthday) 
                                        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
for index,row in customers_df.iterrows():
    cursor.execute(data,((row['CustomerKey'],
                           row['Gender'],
                           row['Name'],
                           row['City'],
                           row['State Code'],
                           row['State'],
                           row['Zip Code'],
                           row['Country'],
                           row['Continent'],
                           row['Birthday']))
                    )
con.commit()

# %%
#create table exchange rates 
create_table_query="""create table exchange_rates(Date date,
                                                  Currency varchar(200),
                                                  Exchange float
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO exchange_rates(Date, Currency, Exchange) 
                                        VALUES (%s,%s,%s)"""
for index,row in exchange_rates_df.iterrows():
    cursor.execute(data,((row['Date'],
                           row['Currency'],
                           row['Exchange'],
                           ))
                    )
con.commit()

# %%
#create table products details
create_table_query="""create table products_details(ProductKey int,
                                        Product_Name varchar(200),
                                        Brand varchar(200),
                                        Color varchar(200),
                                        Unit_Cost_USD float,
                                        Unit_Price_USD float,
                                        SubcategoryKey int,
                                        Subcategory varchar(200),
                                        CategoryKey int,
                                        Category varchar(250)
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO products_details(ProductKey, Product_Name, Brand, Color, Unit_Cost_USD, Unit_Price_USD, SubcategoryKey, Subcategory, CategoryKey, Category) 
                                        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
for index,row in products_df.iterrows():
    cursor.execute(data,((row['ProductKey'],
                           row['Product Name'],
                           row['Brand'],
                           row['Color'],
                           row['Unit Cost USD'],
                           row['Unit Price USD'],
                           row['SubcategoryKey'],
                           row['Subcategory'],
                           row['CategoryKey'],
                           row['Category']))
                    )
con.commit()

# %%
# create table sales details
create_table_query="""create table sales_details(Order_Number int,
                                        Line_Item int,
                                        Order_Date date,
                                        CustomerKey int,
                                        StoreKey int,
                                        ProductKey int,
                                        Quantity int,
                                        Currency_Code varchar(100)
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO sales_details(Order_Number, Line_Item, Order_Date, CustomerKey, StoreKey, ProductKey, Quantity, Currency_Code) 
                                        VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""
for index,row in sales_df.iterrows():
    cursor.execute(data,((row['Order Number'],
                           row['Line Item'],
                           row['Order Date'],
                           row['CustomerKey'],
                           row['StoreKey'],
                           row['ProductKey'],
                           row['Quantity'],
                           row['Currency Code']))
                    )
con.commit()

# %%
# create table stores details
create_table_query="""create table stores_details(StoreKey int,
                                        Country varchar(250),
                                        State varchar(250),
                                        Square_Meters int,
                                        Open_Date date
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO stores_details(StoreKey, Country, State, Square_Meters, Open_Date) 
                                        VALUES (%s,%s,%s,%s,%s)"""
for index,row in stores_df.iterrows():
    cursor.execute(data,((row['StoreKey'],
                           row['Country'],
                           row['State'],
                           row['Square Meters'],
                           row['Open Date']
                           ))
                    )
con.commit()

# %%
#create table customer_sales_merged
create_table_query="""create table customers_sales_merged(CustomerKey int,
                                        Gender varchar(200),
                                        Name varchar(200),
                                        City varchar(200),
                                        StateCode varchar(100),
                                        State varchar(200),
                                        ZipCode varchar(100),
                                        Country varchar(200),
                                        Continent varchar(200),
                                        Birthday date,
                                        Order_Number int,
                                        Line_Item int,
                                        Order_Date date,
                                        StoreKey int,
                                        ProductKey int,
                                        Quantity int,
                                        Currency_Code varchar(100)
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO customers_sales_merged(CustomerKey, Gender, Name, City, StateCode, State, ZipCode, Country, Continent, 
                                      Birthday,Order_Number, Line_Item, Order_Date,StoreKey, ProductKey, Quantity, Currency_Code) 
                                        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
for index,row in customers_sales_merged.iterrows():
    cursor.execute(data,((row['CustomerKey'],
                           row['Gender'],
                           row['Name'],
                           row['City'],
                           row['State Code'],
                           row['State'],
                           row['Zip Code'],
                           row['Country'],
                           row['Continent'],
                           row['Birthday'],
                           row['Order Number'],
                           row['Line Item'],
                           row['Order Date'],
                           row['StoreKey'],
                           row['ProductKey'],
                           row['Quantity'],
                           row['Currency Code']))
                    )
con.commit()

# %%
#create table products_sales_merged
create_table_query="""create table products_sales_merged(ProductKey int,
                                        Product_Name varchar(200),
                                        Brand varchar(200),
                                        Color varchar(200),
                                        Unit_Cost_USD float,
                                        Unit_Price_USD float,
                                        SubcategoryKey int,
                                        Subcategory varchar(200),
                                        CategoryKey int,
                                        Category varchar(250),
                                        Order_Number int,
                                        Line_Item int,
                                        Order_Date date,
                                        CustomerKey int,
                                        StoreKey int,
                                        Quantity int,
                                        Currency_Code varchar(100)
                                        )"""
cursor.execute(create_table_query)
data="""INSERT INTO products_sales_merged(ProductKey, Product_Name, Brand, Color, Unit_Cost_USD, Unit_Price_USD, SubcategoryKey, Subcategory, CategoryKey, Category,
                                          Order_Number, Line_Item, Order_Date, CustomerKey, StoreKey, Quantity, Currency_Code) 
                                        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
for index,row in products_sales_merged.iterrows():
    cursor.execute(data,((row['ProductKey'],
                           row['Product Name'],
                           row['Brand'],
                           row['Color'],
                           row['Unit Cost USD'],
                           row['Unit Price USD'],
                           row['SubcategoryKey'],
                           row['Subcategory'],
                           row['CategoryKey'],
                           row['Category'],
                           row['Order Number'],
                           row['Line Item'],
                           row['Order Date'],
                           row['CustomerKey'],
                           row['StoreKey'],
                           row['Quantity'],
                           row['Currency Code']))
                    )
con.commit()

# %% [markdown]
# # Merging exchange_rates df and Product_sales_merged df on required columns

# %%
product_sales_subset_df=products_sales_merged[['ProductKey','Unit Price USD','Subcategory','Category','Order Number','Order Date','CustomerKey','Quantity','Currency Code']]

# %%
product_sales_subset_df
# Out:
#        ProductKey  Unit Price USD              Subcategory     Category  \
# 0               1           12.99                  MP4&MP3        Audio
# 1               1           12.99                  MP4&MP3        Audio
# 2               1           12.99                  MP4&MP3        Audio
# 3               1           12.99                  MP4&MP3        Audio
# 4               1           12.99                  MP4&MP3        Audio
# ...           ...             ...                      ...          ...
# 62879        2517            3.35  Cell phones Accessories  Cell phones
# 62880        2517            3.35  Cell phones Accessories  Cell phones
# 62881        2517            3.35  Cell phones Accessories  Cell phones
# 62882        2517            3.35  Cell phones Accessories  Cell phones
# 62883        2517            3.35  Cell phones Accessories  Cell phones
#
#        Order Number Order Date  CustomerKey  Quantity Currency Code
# ...

# %%
exchange_rates_subset_df=exchange_rates_df[['Exchange','Currency Code']]
exchange_rates_subset_df
# Out:
#        Exchange Currency Code
# 0        1.0000           USD
# 1        1.1583           CAD
# 2        1.2214           AUD
# 3        0.8237           EUR
# 4        0.6415           GBP
# ...         ...           ...
# 11210    1.0000           USD
# 11211    1.2610           CAD
# 11212    1.2723           AUD
# 11213    0.8238           EUR
# 11214    0.7126           GBP
#
# [11215 rows x 2 columns]

# %%
product_sales_exchange_merged_df=pd.merge(product_sales_subset_df,exchange_rates_subset_df,on='Currency Code')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 product_sales_exchange_merged_df=pd.merge(product_sales_subset_df,exchange_rates_subset_df,on='Currency Code')
#
# File ~\anaconda3\envs\Manishma\Lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File ~\anaconda3\envs\Manishma\Lib\site-packages\pandas\core\reshape\merge.py:885, in _MergeOperation.get_result(self, copy)
#     881     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# ...

# %%
product_sales_exchange_merged_df
